# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'C:\Users\user\Downloads\Crop Prediction dataset.csv')

# %%
X = data[['Temperature', 'Humidity', 'Soil_Moisture', 'Area']]  # Features
y = data['Production']  # Target

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical columns
data['State_Name'] = LabelEncoder().fit_transform(data['State_Name'])
data['District_Name'] = LabelEncoder().fit_transform(data['District_Name'])
data['Season'] = LabelEncoder().fit_transform(data['Season'])
data['Crop'] = LabelEncoder().fit_transform(data['Crop'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(data.isnull().sum())
# Out:
# State_Name         0
# District_Name      0
# Crop_Year          0
# Season             0
# Crop               0
# Temperature        0
# Humidity           0
# Soil_Moisture      0
# Area               0
# Production       215
# dtype: int64

# %%
data = data.dropna(subset=['Production'])

# %%
X = data[['Temperature', 'Humidity', 'Soil_Moisture', 'Area']]
y = data['Production']

# %%
data['Temperature'].fillna(data['Temperature'].mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2016\873006799.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Temperature'].fillna(data['Temperature'].mean(), inplace=True)

# %%
data = data.dropna()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
import joblib
joblib.dump(model, 'crop_production_model.pkl')
# Out:
# ['crop_production_model.pkl']

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
