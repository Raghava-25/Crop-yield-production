# %% [markdown]
# # End-to-End Story Telling project on crop yield dataset

# %% [markdown]
# # **OBJECTIVE**
#
# Predicting the yield of crop to estimate the crop in a
# certain year to control the price rates.This model helps in predicting the crop yield by analyzing
# factors like location, season, and crop type  through machine learning on collected datasets.

# %% [markdown]
# ## Steps to Conduct EDA

# %% [markdown]
# ## Step 1: Data Collection and Loading

# %% [markdown]
# obtained the dataset (Crop Prediction dataset.csv).
#
# loading the dataset using required libraries in python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 🔍 Dataset Features:
#
# State Name 🌍: The name of the state where the agricultural data is recorded.
#
# District Name 🏙️: The specific district within the state where the data is collected.
#
# Crop Year 🌾📅: The year in which the crop is grown or harvested.
#
# Season 🌱🌦️: The agricultural season (e.g., Rabi, Kharif) during which the crop is cultivated.
#
# Crop 🌾🌽: The specific type of crop being grown (e.g., Gram, rice).
#
# Temperature 🌡️: The temperature recorded during the crop growing period.
#
# Humidity 💧: The humidity level during the crop growing period.
#
# Soil Moisture 🌱💧: The level of moisture present in the soil during the crop growth phase.
#
# Area 📏🌾: The total area of land used for cultivating the crop.
#
# Production 🏆📊: The total yield or amount of crop produced.

# %%
df = pd.read_csv(r"C:\Users\Salmon Studio\Desktop\JAHEER\Crop Prediction dataset.csv")
df
# Out:
#                        State_Name District_Name  Crop_Year       Season  \
# 0     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3     Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4     Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                           ...           ...        ...          ...
# 4995               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4996               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4997               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4998               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4999               Andhra Pradesh       KURNOOL       2003  Whole Year
#
#                      Crop  Temperature  Humidity  Soil_Moisture     Area  \
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %% [markdown]
# The "Crop Prediction dataset.csv" dataset contains of **5000 rows and 10 columns**
# with ( 4 - integer values, 2 - float values and 4 - object values),
# dataset size = 343 kb

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop',
#        'Temperature', 'Humidity', 'Soil_Moisture', 'Area', 'Production'],
#       dtype='object')

# %%
df.describe(include = "all")
# Out:
#             State_Name District_Name    Crop_Year       Season  Crop  \
# count             5000          5000  5000.000000         5000  5000
# unique               2            10          NaN            4    70
# top     Andhra Pradesh        KADAPA          NaN  Kharif       Rice
# freq              4797           824          NaN         2117   253
# mean               NaN           NaN  2005.778000          NaN   NaN
# std                NaN           NaN     5.166474          NaN   NaN
# min                NaN           NaN  1997.000000          NaN   NaN
# 25%                NaN           NaN  2002.000000          NaN   NaN
# 50%                NaN           NaN  2005.000000          NaN   NaN
# 75%                NaN           NaN  2011.000000          NaN   NaN
# max                NaN           NaN  2014.000000          NaN   NaN
#
#         Temperature     Humidity  Soil_Moisture           Area    Production
# ...

# %% [markdown]
# Here , **State_Name**,**District_Name**,**Crop** and **Season** are the categorical columns and the **remaining** are the numerical columns

# %% [markdown]
# ## Step 2: Data Cleaning
# Check for missing values and handle them appropriately.
#
# Correct any inconsistencies in the data.
#
# Ensure all data types are appropriate.

# %%
# Check for missing values
print(df.isnull().sum())

# Fill missing values or drop them if necessary
df.ffill(inplace=True)

# Check data types
print(df.dtypes)
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Temperature      0
# Humidity         0
# Soil_Moisture    0
# Area             0
# Production       0
# dtype: int64
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Temperature        int64
# Humidity           int64
# Soil_Moisture      int64
# Area             float64
# Production       float64
# dtype: object

# %% [markdown]
# It checks for The missing values and use the fill function to check for missing values
#
# In my case there are no null values so it shows zero.

# %% [markdown]
# ## Step 3: Data Visualization
# Use visualizations to understand the distribution and relationships between variables.
# Create histograms, box plots, scatter plots, bar charts, and heatmaps.

# %%
plt.subplot(221)
df['State_Name'].value_counts().plot(kind='bar', title='States in Dataset', figsize=(16,9))
plt.xticks(rotation=0)

plt.subplot(222)
df['Season'].value_counts().plot(kind='bar', title='Seasons of Crop')
plt.xticks(rotation=0)

plt.figure(figsize=(16, 8))
df['Crop'].value_counts().plot(kind='bar', title='Crops Grown')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1. State-wise Distribution of Data
#    - The dataset is primarily dominated by data from Andhra Pradesh, contributing a majority of the entries.
#    - A small fraction of data belongs to Andaman and Nicobar Islands, indicating limited representation from this region.
#    - This disparity in data distribution suggests that predictions or insights may be skewed towards Andhra Pradesh, given its larger sample size.
#
# ### 2. Season-wise Distribution of Crops
#    - The Kharif season has the highest number of crop entries in the dataset, followed by the Rabi season.
#    - There is a significant portion of crops that are grown throughout the whole year, highlighting versatile crop varieties in the dataset.
#    - The Autumn season has negligible entries, indicating either limited cultivation during this period or a lack of data for this season.
#
# ### 3. Crop Variety Distribution
#    - The dataset contains a wide variety of crops, with certain crops such as Rice, Groundnut, and Maize being the most frequently represented.
#    - Lesser-known or niche crops such as Guar seed, Tobacco, and Jute have fewer entries, suggesting that these crops are grown less frequently or only in specific regions.
#    - The diversity of crops in the dataset can help build robust models for predicting crop suitability, but the imbalance in crop frequency may require appropriate techniques like oversampling or under-sampling to avoid bias.

# %%
# Histograms for Temperature and Humidity
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.histplot(df['Temperature'], kde=True, ax=axes[0], color='orange')
axes[0].set_title('Temperature Distribution')
axes[0].set_xlabel('Temperature')

sns.histplot(df['Humidity'], kde=True, ax=axes[1], color='blue')
axes[1].set_title('Humidity Distribution')
axes[1].set_xlabel('Humidity')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Temperature and Humidity Distributions (Histogram with KDE)
# These histograms, combined with KDE (Kernel Density Estimation), depict the distribution of temperature and humidity across the dataset.
#
# ### Key Observations:
# - Temperature:
#   - Most values are concentrated between 34–36°C, likely representing optimal conditions for the crops analyzed.
# - Humidity:
#   - Distribution peaks around 40%, 45%, and 55%, suggesting a mix of growing conditions and crop types.

# %%
# Plot the correlation heatmap for numerical columns
plt.figure(figsize=(10, 6))
corr = df[['Temperature', 'Humidity', 'Soil_Moisture', 'Area', 'Production']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', vmax=1, vmin=-1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Correlation Heatmap
# The heatmap visualizes the correlation between key variables: Temperature, Humidity, Soil Moisture, Area, and Production.
#
# ### Key Observations:
# - Temperature vs. Humidity: Strong negative correlation (-0.7), indicating that higher temperatures typically coincide with lower humidity.
# - Soil Moisture:
#   - Positively correlated with Humidity (0.81), indicating that higher humidity leads to higher soil moisture levels.
#   - Moderately correlated with Production (0.29), showing that soil moisture impacts production to some extent.
# - Area vs. Production: Low positive correlation (0.031), implying that merely increasing the cultivated area doesn’t guarantee higher yields.

# %%
# Line plot for yearly trends in production
plt.figure(figsize=(10, 6))
yearly_trends = df.groupby('Crop_Year')['Production'].sum().reset_index()
yearly_trends['Crop_Year'] = yearly_trends['Crop_Year'].astype(str)
sns.lineplot(data=yearly_trends, x='Crop_Year', y='Production', marker='o')
plt.title('Yearly Trends in Production')
plt.xlabel('Year')
plt.xticks(rotation = 25)
plt.ylabel('Total Production (Metric Tons)')
plt.show()

# %% [markdown]
# ## Yearly Trends in Production (Line Plot)
# This line plot showcases the annual production trends (in metric tons) over the recorded years.
#
# ### Key Observations:
# - Growth Period: A steady rise in crop production is observed until the early 2000s.
# - Fluctuations: The period between 2005–2008 experienced significant production dips, possibly due to environmental, policy, or market conditions.
# - Recovery: Recent years indicate stabilization and recovery, with production nearing the historical peaks.

# %%
# Scatter plot for Soil Moisture vs Production
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Soil_Moisture', y='Production', hue='Season', alpha=0.6)
plt.title('Soil Moisture vs Production')
plt.xlabel('Soil Moisture')
plt.ylabel('Production (Metric Tons)')
plt.legend(title='Season')
plt.show()

# %% [markdown]
# ## Soil Moisture vs. Production (Scatter Plot)
# This scatter plot highlights the relationship between soil moisture and crop production, segmented by seasons: Kharif, Rabi, Whole Year, and Autumn.
#
# ### Key Observations:
# - High-Production Zone: Soil moisture values between 50–62.5 are associated with the highest crop production.
# - Seasonal Clusters: Each season exhibits distinct clusters of production levels, emphasizing the role of seasonality in crop yield.
# - Impact of Soil Moisture: Higher soil moisture values (above 62.5) don't necessarily correlate with higher production, suggesting diminishing returns.

# %% [markdown]
# ## Step 4: Descriptive Statistics
# Calculate and interpret measures of central tendency and dispersion.
# Summarize key statistics for numerical variables.

# %%
# Descriptive statistics for the entire dataset
print(df.describe())

# Central tendency and dispersion for Production 🏆📊
mean_production = df['Production'].mean()
median_production = df['Production'].median()
std_production = df['Production'].std()

print(f"Mean Production: {mean_production}")
print(f"Median Production: {median_production}")
print(f"Standard Deviation of Production: {std_production}")
# Out:
#          Crop_Year  Temperature     Humidity  Soil_Moisture           Area  \
# count  5000.000000  5000.000000  5000.000000    5000.000000    5000.000000
# mean   2005.778000    34.446400    44.772600      53.108000   14945.509014
# std       5.166474     3.498739     6.662745       5.259113   56953.835747
# min    1997.000000    25.000000    35.000000      45.000000       0.200000
# 25%    2002.000000    34.000000    40.000000      50.000000     126.000000
# 50%    2005.000000    36.000000    42.000000      54.000000     885.500000
# 75%    2011.000000    36.000000    50.000000      55.000000    5291.500000
# max    2014.000000    37.000000    55.000000      62.000000  877029.000000
#
#          Production
# count  5.000000e+03
# mean   1.986902e+06
# std    3.281148e+07
# min    0.000000e+00
# 25%    1.237500e+02
# 50%    1.369500e+03
# 75%    1.490000e+04
# max    7.801620e+08
# Mean Production: 1986902.1147979998
# Median Production: 1369.5
# ...

# %% [markdown]
# By this we can see that mean,median values of crop production as we noticed in the above plots

# %% [markdown]
# ## Step 5: Identify Patterns and Relationships
# Use correlation analysis to identify relationships between variables.
# Perform bivariate and multivariate analyses.

# %%
# Correlation between Temperature and Production
correlation_temp_production = df['Area'].corr(df['Production'])
print(f"Correlation between Temperature and Production: {correlation_temp_production}")

# Grouped analysis of average values by Crop
grouped_by_crop = df.groupby('Crop')[['Temperature', 'Humidity', 'Soil_Moisture', 'Area']].mean().reset_index()
print(grouped_by_crop)
# Out:
# Correlation between Temperature and Production: 0.031446450411164534
#                          Crop  Temperature   Humidity  Soil_Moisture  \
# 0                    Arecanut    34.739130  44.108696      52.565217
# 1                   Arhar/Tur    34.721893  44.485207      53.029586
# 2                       Bajra    34.012121  45.333333      53.133333
# 3                      Banana    34.739130  44.554348      53.043478
# 4   Beans & Mutter(Vegetable)    34.538462  45.384615      53.769231
# ..                        ...          ...        ...            ...
# 65                     Varagu    33.200000  48.400000      55.800000
# 66                      Wheat    34.729167  43.958333      52.791667
# 67               other fibres    35.000000  40.000000      48.500000
# 68         other misc. pulses    36.285714  40.428571      51.714286
# 69             other oilseeds    34.361111  44.888889      53.944444
#
#             Area
# 0     837.039565
# 1   10220.207101
# ...

# %% [markdown]
# The correlation between production and area is relatively strong and positive, indicating that larger areas of land tend to produce more crop yields.
#
# This makes sense because larger areas are typically able to accommodate more crops, leading to higher production.

# %% [markdown]
# ## Step 6: Outlier Detection
# Identify and handle outliers using visualizations and statistical methods.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot for outlier detection in Production 🏆📊
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['Temperature'])
plt.title('Box Plot for Temperature')
plt.show()

# Handling outliers (example: using IQR method for Production 🏆📊)
q1_temp = df['Temperature'].quantile(0.25)
q3_temp = df['Temperature'].quantile(0.75)
iqr_temp = q3_temp - q1_temp

# Define outliers for Production 🏆📊
outliers_temp = df[(df['Temperature'] < (q1_temp - 1.5 * iqr_temp)) | (df['Temperature'] > (q3_temp + 1.5 * iqr_temp))]
print("Outliers in Temperature:")
print(outliers_temp)
# Out:
# Outliers in Temperature:
#                        State_Name District_Name  Crop_Year       Season  \
# 8     Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 17    Andaman and Nicobar Islands      NICOBARS       2001  Whole Year
# 26    Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
# 35    Andaman and Nicobar Islands      NICOBARS       2003  Whole Year
# 44    Andaman and Nicobar Islands      NICOBARS       2004  Whole Year
# ...                           ...           ...        ...          ...
# 4958               Andhra Pradesh       KURNOOL       2003  Kharif
# 4967               Andhra Pradesh       KURNOOL       2003  Rabi
# 4976               Andhra Pradesh       KURNOOL       2003  Rabi
# 4985               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4994               Andhra Pradesh       KURNOOL       2003  Whole Year
#
#                 Crop  Temperature  Humidity  Soil_Moisture    Area  Production
# ...

# %% [markdown]
# The box plot for temparature shows that the majority of the data points falls between 34 and 36 degrees with a few outliers below 26 degrees.

# %% [markdown]
# ## Step 7: Hypothesis Testing
# Formulate hypotheses based on initial observations and test them using statistical methods.

# %%
from scipy.stats import ttest_ind

# Hypothesis: Crops in Maharashtra have different production compared to crops in Punjab
ap_crops = df[df['State_Name'] == 'Andhra Pradesh']['Production']
andaman_crops = df[df['State_Name'] == 'Andaman and Nicobar Islands']['Production']

# Perform t-test
t_stat, p_value = ttest_ind(ap_crops, andaman_crops)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -0.6876245991382267, P-value: 0.4917211211198571

# %% [markdown]
# The t-test results show no significant difference in crop production between Andhra Pradesh and Andaman & Nicobar Islands.(p-value > 0.05).

# %% [markdown]
# ## Step 8: Summarize Findings
# Compile insights and key findings from the EDA into a report.
# Use visualizations and statistical summaries to present your results.

# %%
import matplotlib.pyplot as plt

# Group by 'Season 🌱🌦️' (e.g., Kharif vs Rabi) and calculate mean for selected features
df.groupby('Season')[['Humidity', 'Temperature', 'Soil_Moisture']].mean().T.plot(kind='barh', figsize=(10, 10))

plt.title('Mean Values of Production, Temperature, and Soil Moisture by Season')
plt.xlabel('Mean Value')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# **Key Insights on Crop Yield Prediction:**
#
# **Seasonal Impact:**
#
# Rabi and Kharif seasons have distinct effects on crop yield due to different weather patterns. For example, water-loving crops like rice do better in Kharif, while dry-season crops like wheat thrive in Rabi.
#
# **Temperature:**
#
# Crops have an optimal temperature range for growth. Too high or too low temperatures can reduce yield. Some crops may perform better in hotter conditions (e.g., maize), while others need cooler temperatures (e.g., wheat).
#
# **Humidity:**
#
# High humidity helps some crops (e.g., rice), but excessive moisture can promote diseases. Crops like wheat may prefer drier conditions.
#
# **Soil Moisture:**
#
# Optimal soil moisture is crucial for good crop growth. Both too much and too little moisture can harm yield. Irrigation may be necessary in areas with unpredictable rainfall.
#
# **Area of Land:**
#
# Larger land areas typically lead to higher production, but only if other factors like soil and climate are favorable. Efficient land use is key.
#
# **Crop Type:**
#
# Different crops have specific needs for water, temperature, and soil. For example, maize requires more water and heat than wheat.
#
# **Yearly Trends:**
#
# Analyzing production by year helps identify trends and anomalies, such as poor yields caused by weather events or diseases.
#
# **Geographical Factors:**
#
# Crops perform differently across states and districts due to variations in climate and soil. Tailored strategies are needed for different regions.
#
# **Outliers:**
#
# Extremely high or low yields might indicate unusual weather conditions or errors in data, and investigating these can help improve predictions.
#
# **Correlations**
#
# Factors like temperature, humidity, and soil moisture often show strong links to yield. Understanding these relationships helps identify what impacts yield most.

# %% [markdown]
# ## Step 9: Building a Prediction Model
# Making a prediction model by training and testing.

# %%
df['Production'] = df['Production'].fillna(df['Production'].mean())
df
# Out:
#                        State_Name District_Name  Crop_Year       Season  \
# 0     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2     Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3     Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4     Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                           ...           ...        ...          ...
# 4995               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4996               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4997               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4998               Andhra Pradesh       KURNOOL       2003  Whole Year
# 4999               Andhra Pradesh       KURNOOL       2003  Whole Year
#
#                      Crop  Temperature  Humidity  Soil_Moisture     Area  \
# ...

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
print(df.State_Name.unique())
print('Total count of states and Union Territories:', len(df.State_Name.unique()))
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh']
# Total count of states and Union Territories: 2

# %%
df['Yield'] = (df['Production'] / df['Area'])
df.head(10)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop  Temperature  Humidity  Soil_Moisture     Area  \
# 0             Arecanut           36        35             45   1254.0
# 1  Other Kharif pulses           37        40             46      2.0
# ...

# %%
data = df.drop(['State_Name','District_Name','Season','Crop'], axis = 1)

# %%
data.corr()
# Out:
#                Crop_Year  Temperature  Humidity  Soil_Moisture      Area  \
# Crop_Year       1.000000     0.000161 -0.000671      -0.000487 -0.031042
# Temperature     0.000161     1.000000 -0.696280      -0.286586  0.006918
# Humidity       -0.000671    -0.696280  1.000000       0.812481 -0.008278
# Soil_Moisture  -0.000487    -0.286586  0.812481       1.000000 -0.013793
# Area           -0.031042     0.006918 -0.008278      -0.013793  1.000000
# Production      0.012297     0.002834 -0.005306      -0.001973  0.031446
# Yield           0.036048    -0.021894 -0.001993      -0.010123 -0.008033
#
#                Production     Yield
# Crop_Year        0.012297  0.036048
# Temperature      0.002834 -0.021894
# Humidity        -0.005306 -0.001993
# Soil_Moisture   -0.001973 -0.010123
# Area             0.031446 -0.008033
# Production       1.000000  0.539586
# Yield            0.539586  1.000000

# %%
sns.heatmap(data.corr(), annot =True, fmt='.4f', cmap='coolwarm', vmax=1, vmin=-1)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
dummy = pd.get_dummies(data)
dummy
# Out:
#       Crop_Year  Temperature  Humidity  Soil_Moisture     Area  Production  \
# 0          2000           36        35             45   1254.0      2000.0
# 1          2000           37        40             46      2.0         1.0
# 2          2000           36        41             50    102.0       321.0
# 3          2000           37        42             55    176.0       641.0
# 4          2000           36        40             54    720.0       165.0
# ...         ...          ...       ...            ...      ...         ...
# 4995       2003           36        35             45    148.0      8420.0
# 4996       2003           37        40             46    435.0     31537.0
# 4997       2003           36        41             50     15.0       108.0
# 4998       2003           37        42             55  13777.0     17318.0
# 4999       2003           36        40             54  19358.0    293269.0
#
#           Yield
# 0      1.594896
# 1      0.500000
# ...

# %% [markdown]
# <b><i> Splitting dataset into train and test dataset </i></b>

# %%
from sklearn.model_selection import train_test_split

x = dummy.drop(["Production","Yield"], axis=1)
y = dummy["Production"]

# Splitting data set - 25% test dataset and 75% 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=42)

print("x_train :",x_train.shape)
print("x_test :",x_test.shape)
print("y_train :",y_train.shape)
print("y_test :",y_test.shape)
# Out:
# x_train : (3750, 5)
# x_test : (1250, 5)
# y_train : (3750,)
# y_test : (1250,)

# %%
print(x_train)
print(y_train)
# Out:
#       Crop_Year  Temperature  Humidity  Soil_Moisture     Area
# 4884       2002           34        55             62  55276.0
# 3163       2013           36        40             54  13556.0
# 490        2003           36        40             54     30.0
# 862        2013           35        50             59  11416.0
# 1740       2014           37        42             55   1642.0
# ...         ...          ...       ...            ...      ...
# 4426       2007           35        50             59  16000.0
# 466        2003           35        50             59     22.0
# 3092       2012           34        45             52   2980.0
# 3772       2010           37        40             46      6.0
# 860        2013           34        45             52      2.0
#
# [3750 rows x 5 columns]
# 4884      49748.0
# 3163      82027.0
# 490         217.0
# 862        5366.0
# 1740        501.0
#           ...
# 4426    1655000.0
# 466           7.0
# 3092       1299.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# creating the dataset
year = [2012,2013,2014]
values = []
data1 = pd.DataFrame(df)
for x in range(3):
  curyearsum=0
  count=0
  for y in range(1000):
    if(data1.iloc[y]["Crop_Year"] == year[x]):
      count+=1;
      curyearsum += data1.iloc[x]["Humidity"]
  values.append(curyearsum/count)
fig = plt.figure(figsize = (7, 5))
 
# creating the bar plot
x = np.array(["2012","2013","2014"])
y = np.array(values)
plt.xlabel("year")
plt.ylabel("mean value of humidity")
plt.title("mean value of humidity of three years")
plt.bar(x,y,color ='maroon', width = 0.4)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# creating the dataset
year = [2012,2013,2014]
values = []
data1 = pd.DataFrame(df)
for x in range(3):
  curyearsum=0
  count=0
  for y in range(1000):
    if(data1.iloc[y]["Crop_Year"] == year[x]):
      count+=1;
      curyearsum += data1.iloc[x]["Temperature"]
  values.append(curyearsum/count)
fig = plt.figure(figsize = (7, 5))
 
# creating the bar plot
x = np.array(["2012","2013","2014"])
y = np.array(values)
plt.xlabel("year")
plt.ylabel("mean value of Temperature")
plt.title("mean value of Temperature of three years")
plt.bar(x,y,color ='maroon', width = 0.4)
plt.show()

# %% [markdown]
# # **Linear Regression**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
axes[0].scatter(df['Temperature'], df['Production'], color='red')
axes[1].scatter(df['Soil_Moisture'], df['Production'], color='blue')
axes[0].set_title("Temperature vs Production")
axes[1].set_title("Soil_Moisture vs Production")
axes[0].set_ylabel("Production")
axes[0].set_xlabel("Temperture")
axes[1].set_ylabel("Production")
axes[1].set_xlabel("Soil_Moisture")
plt.show()

# %%
# Training the Simple Linear Regression model .

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_predict = model.predict(x_test)
lr_predict
# Out:
# array([2340488.44744092, 1482540.43906972, 4135328.79116926, ...,
#        6485169.32962433, 1751602.35840493, 2049827.04599231],
#       shape=(1250,))

# %%
from sklearn.metrics import mean_squared_error
lr_predict = model.predict(x_test)
scores_regr = mean_squared_error(y_test, lr_predict)
print(scores_regr)
# print(mean_squared_error(y_train, lr_predict))
# Out:
# 510901271513776.9

# %%
# Predicting the test Results 

lr_predict = model.predict(x_test)
lr_predict
# Out:
# array([2340488.44744092, 1482540.43906972, 4135328.79116926, ...,
#        6485169.32962433, 1751602.35840493, 2049827.04599231],
#       shape=(1250,))

# %%
model.score(x_test,y_test)
# Out:
# -0.004391352510309421

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test,lr_predict)
print("R2 score : ",r)
# Out:
# R2 score :  -0.004391352510309421

# %%
plt.scatter(x = np.arange(0,50), y = y_test[:50])
plt.scatter(x = np.arange(0,50), y = (lr_predict[:50]))
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')
# Out:
# C:\Users\Salmon Studio\AppData\Local\Temp\ipykernel_7088\4067277936.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Clearly, the dataset is not good for linear regression.

# %% [markdown]
# R2 score: This is pronounced as R-squared, and this score refers to the coefficient of determination.
# This tells us how well the unknown samples will be predicted by our model.

# %% [markdown]
# # <b> Decision Tree </b>

# %%
# Training model 
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 5)
regressor.fit(x_train,y_train)

# Predicting results
decisiontree_predict = regressor.predict(x_test)
decisiontree_predict
# Out:
# array([2.72050e+04, 2.50000e+02, 4.82990e+05, ..., 1.55325e+05,
#        8.09200e+03, 1.37520e+04], shape=(1250,))

# %%
regressor.score(x_test,y_test)
# Out:
# -1.676741236046074

# %%
plt.scatter(x = np.arange(0,50), y = y_test[:50])
plt.scatter(x = np.arange(0,50), y = (decisiontree_predict[:50]))
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Decision Tree ')
# Out:
# Text(0.5, 1.0, 'Decision Tree ')

# %%
# Calculating R2 score :

from sklearn.metrics import r2_score
r2 = r2_score(y_test,decisiontree_predict)
print("R2 score : ",r2)
# Out:
# R2 score :  -1.676741236046074

# %% [markdown]
# # **Random Forest Algorithm**

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 11)
model.fit(x_train,y_train)
rf_predict = model.predict(x_test)
rf_predict
# Out:
# array([6.29518182e+03, 2.07575758e+02, 4.61239545e+05, ...,
#        6.31004545e+05, 4.59309091e+03, 3.67814873e+06], shape=(1250,))

# %%
model.score(x_test,y_test)
# Out:
# -0.7983928463446268

# %%
# Calculating R2 score

from sklearn.metrics import r2_score
r1 = r2_score(y_test,rf_predict)
print("R2 score : ",r1)
# Out:
# R2 score :  -0.7983928463446268

# %%
# Calculating Adj. R2 score: 

Adjr2_1 = 1 - (1-r1)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_1))
# Out:
# Adj. R-Squared : -0.8056211134119284

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Random Forest Regression')
# Out:
# C:\Users\Salmon Studio\AppData\Local\Temp\ipykernel_7088\551929062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\Salmon Studio\AppData\Local\Temp\ipykernel_7088\551929062.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.scatter(x = np.arange(0,50), y = y_test[:50])
plt.scatter(x = np.arange(0,50), y = (rf_predict[:50]))
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Random Forest')
# Out:
# Text(0.5, 1.0, 'Random Forest')

# %% [markdown]
# <b> Comparison between Linear Regression Algorithm and Random Forest Algorithm </b>

# %% [markdown]
# 1. Linear regression algorithm is not at all accurate for this kind of prediction.
# 2. Random Forest Algorithm has higher accuracy ( between 85 % to 90% ), but it is slow.

# %% [markdown]
# The production is the dependent value and all the remaining values are independent values.

# %% [markdown]
# **Conclusion:**
#
# the factors influencing crop yield, including the significant role of season, temperature, and soil moisture. Understanding these relationships can help optimize agricultural practices and improve crop productivity across regions & the random forest gives more accurate predictions than the other algorithms.

# %% [markdown]
# <center> <h2>THE END<h2> </center>
